# %% [markdown]
# Веса изделий следуют нормальному распределению с дисперсией 9 и средним
# арифметическим 50.
# Веса ниже 45 г считаются браком. Какая доля изделий бракованная?

# %%
d = 9
mean = 50
x = 45

std = d ** 0.5
std

p = (x - mean)/std
p
# Out:
# -1.6666666666666667

# %% [markdown]
# Итак, мы можем воспользоваться этой нормированной величиной -1.67 и по таблице ниже определим, что 0.0475 – такая доля изделий имеет вес меньше 45 г.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
d = 9
mean = 50
x = 56

std = d ** 0.5
std

p = (x - mean)/std
p
# Out:
# 2.0

# %% [markdown]
# Итак, мы можем воспользоваться этой нормированной величиной 2 и по таблице  определим, что 0.9772 – такая доля изделий имеет вес выше 56.

# %%
d = 9
mean = 50
x = 55

std = d ** 0.5
std

p = (x - mean)/std
p
# Out:
# 1.6666666666666667

# %% [markdown]
# Найдите среднее квадратичное отклонение случайной величины X, равномерно
# распределенной на отрезке [-2, 7]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = -2
b = 7
d = ((b - a)**2)/ 12
print(round(d**0.5, 2))
# Out:
# 2.6
